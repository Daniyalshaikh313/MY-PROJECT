# %% [markdown]
# <!-- from IPython.core.display import display, HTML
#
# iframe_html = """ -->
# <div style="
#     margin: 20px auto;
#     width: 90%;
#     max-width: 960px;
#     background-color: orange;
#     border: 2px solid #FF8C00;
#     border-radius: 10px;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.2);
#     text-align: center;
#     padding: 20px;
# ">
#     <img src="https://cdn.iconscout.com/icon/free/png-256/kaggle-3628725-3029320.png" alt="Kaggle Logo" style="width: 50px; margin-bottom: 10px;">
#     <h2 style="color: white; font-family: Arial, sans-serif; margin: 10px 0;">🍽️ Swiggy Restaurant Analysis 🚀 🍹</h2>
# </div>
# <!-- """
# display(HTML(iframe_html)) -->

# %%
import plotly.express as px
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("swiggy.csv")
df
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings  \
# ...

# %% [markdown]
# <!-- from IPython.core.display import display, HTML
#
# # HTML content with styled box
# iframe_html = """ -->
# <div style="
#     margin: 20px auto;
#     width: 90%;
#     max-width: 960px;
#     background-color: orange;
#     border: 2px solid #FF8C00;
#     border-radius: 10px;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.2);
#     text-align: center;
#     padding: 20px;
# ">
#     <img src="https://cdn.iconscout.com/icon/free/png-256/kaggle-3628725-3029320.png" alt="Kaggle Logo" style="width: 50px; margin-bottom: 10px;">
#     <h2 style="color: white; font-family: Arial, sans-serif; margin: 10px 0;">Data Overview</h2>
# </div>

# %%
df.sample(10)
# Out:
#           ID                     Area       City  \
# 1458   81489                Begampura      Surat
# 5952  447106                   Dumdum    Kolkata
# 7976  307143                Vastrapur  Ahmedabad
# 2628  251092           Navsari Bazaar      Surat
# 199     8501                 Alwarpet    Chennai
# 4474  384092              Rajajinagar  Bangalore
# 7696  191644              Gidc Naroda  Ahmedabad
# 5657  437299  Nallakunta & Vidyanagar  Hyderabad
# 5839  443068  Kothapet & Dilsukhnagar  Hyderabad
# 2137  181091                  Tiljala    Kolkata
#
#                                    Restaurant  Price  Avg ratings  \
# 1458                             Cinera Hotel  300.0          4.1
# 5952                                  Wakhani  300.0          2.9
# 7976                  Bread Box Sandesh Press  200.0          2.9
# 2628                         Badshahi Biryani  200.0          3.1
# 199                            Dhabba Express  500.0          4.0
# ...

# %%
df.isnull().sum()
# Out:
# ID               0
# Area             0
# City             0
# Restaurant       0
# Price            0
# Avg ratings      0
# Total ratings    0
# Food type        0
# Address          0
# Delivery time    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8680 entries, 0 to 8679
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             8680 non-null   int64
#  1   Area           8680 non-null   object
#  2   City           8680 non-null   object
#  3   Restaurant     8680 non-null   object
#  4   Price          8680 non-null   float64
#  5   Avg ratings    8680 non-null   float64
#  6   Total ratings  8680 non-null   int64
#  7   Food type      8680 non-null   object
#  8   Address        8680 non-null   object
#  9   Delivery time  8680 non-null   int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 678.3+ KB

# %%
df.nunique()
# Out:
# ID               8680
# Area              833
# City                9
# Restaurant       7865
# Price             120
# Avg ratings        30
# Total ratings       8
# Food type        3734
# Address          2339
# Delivery time      81
# dtype: int64

# %%
number_columns = len(df.columns)
number_columns
# Out:
# 10

# %% [markdown]
# <!-- from IPython.core.display import display, HTML
#
# # HTML content with styled box
# iframe_html = """ -->
# <div style="
#     margin: 20px auto;
#     width: 90%;
#     max-width: 960px;
#     background-color: orange;
#     border: 2px solid #FF8C00;
#     border-radius: 10px;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.2);
#     text-align: center;
#     padding: 20px;
# ">
#     <img src="https://cdn.iconscout.com/icon/free/png-256/kaggle-3628725-3029320.png" alt="Kaggle Logo" style="width: 50px; margin-bottom: 10px;">
#     <h2 style="color: white; font-family: Arial, sans-serif; margin: 10px 0;">Data Analysis</h2>
# </div>

# %%
Top_10_City	= df['City'].value_counts()
Top_10_City
fig = px.bar(Top_10_City, x=Top_10_City.index, y=Top_10_City.values, title='Top 10 City with Most Restaurants')

fig.update_xaxes(title_text='City', title_font_color='white')  
fig.update_yaxes(title_text='Number of Restaurants', title_font_color='white')  

fig.update_layout(
    paper_bgcolor='black', 
    plot_bgcolor='black',
    font_color='white'
)

fig.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 6))
ax = sns.histplot(data=df, x='Price', kde=False, color='blue')

ax.set_title('Distribution of Restaurant Prices on Swiggy', color='white', fontsize=16)
ax.set_xlabel('Price', color='white', fontsize=12)
ax.set_ylabel('Count', color='white', fontsize=12)

ax.set_facecolor('black') 
plt.gcf().set_facecolor('black')  
ax.tick_params(colors='white') 
ax.grid(color='gray', linestyle='--', linewidth=0.5)  

plt.tight_layout()
plt.show()

# %%
fig = px.scatter(df, x='Price', y='Avg ratings', title='Correlation Between Restaurant Price and average ratings', color_discrete_sequence=['red'])
fig.update_layout(template="plotly_dark") 

fig.show()

# %%
Top_rating_Resturant_in_Mumbai = df[(df['City']=='Mumbai')&(df['Avg ratings']==5.0)]
Top_rating_Resturant_in_Mumbai
# Out:
#           ID               Area    City               Restaurant  Price  \
# 3894  357553        Bandra East  Mumbai  Diamond Market Pizza Jp  600.0
# 5424  427280            Chembur  Mumbai          Get In My Belly  500.0
# 5425  427282            Chembur  Mumbai       The Asian Pavilion  200.0
# 5519  431996  Scruz Bandra East  Mumbai              Cafe Kokomo  400.0
# 5885  444623       Andheri East  Mumbai         Nivala Apka Apna  200.0
# 6930   50343                Bkc  Mumbai                    Snaxx  500.0
#
#       Avg ratings  Total ratings                         Food type  \
# 3894          5.0             20                           Italian
# 5424          5.0             20                            Indian
# 5425          5.0             20                    Asian  Chinese
# 5519          5.0             50  Beverages,Snacks,Desserts,Bakery
# 5885          5.0             20       North Indian,Chinese,Indian
# ...

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import warnings
warnings.simplefilter(action='ignore', category=UserWarning)


import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8))
ax = sns.barplot(
    data=Top_rating_Resturant_in_Mumbai, 
    x='Restaurant', 
    y='Avg ratings', 
    palette='Reds_r'  
)

ax.set_title('Top-Rated Restaurants in Mumbai', color='white', fontsize=18, fontweight='bold')
ax.set_xlabel('Restaurant', color='white', fontsize=12, labelpad=8)
ax.set_ylabel('Average Ratings', color='white', fontsize=12, labelpad=8)


ax.set_xticklabels(ax.get_xticklabels(), rotation=40, horizontalalignment='right', color='white', fontsize=12)

ax.set_facecolor('black')  
plt.gcf().set_facecolor('black') 
ax.tick_params(colors='white')  
ax.grid(color='gray', linestyle='--', linewidth=0.3)  


for container in ax.containers:
    ax.bar_label(container, fmt='%.1f', label_type='edge', color='white', fontsize=10)

plt.tight_layout()
plt.show()
